# %% [markdown]
# <a href="https://colab.research.google.com/github/xbetoxsantos-web/curso-python-piva/blob/main/Boolean.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
''' corresponde a dois elementos , oy verdadeiro ou falso
ou truel ou false
ou 0 ou 1'''

# True e False sempre começam com letra maiuscula

True
False
flag= False
type(flag)
print(flag)
flag.real
# Out:
# False
# 0
