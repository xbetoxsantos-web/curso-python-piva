# %% [markdown]
# <a href="https://colab.research.google.com/github/xbetoxsantos-web/curso-python-piva/blob/main/Escopo_Conversao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=0
y=0

print('Gy - ', y)
print('Gx - ', x)

def funcao():
    y=4
    print('Fy - ', y)
    print('Fx - ', x)

funcao()
print('Gy - ', y)
print('Gx - ', x)
# Out:
# Gy -  0
# Gx -  0
# Fy -  4
# Fx -  0
# Gy -  0
# Gx -  0

# %%
#Conversão

y=6
x=float(y)
print(x)
type(x)

z=int(x)
print(z)
type(z)

x=6.7
z=int(x)
print(z)

z=round(x)
print(z)

numero='45'
n=int(numero)
print(n)

n=float(numero)
print(n)
# Out:
# 6.0
# 6
# 6
# 7
# 45
# 45.0
