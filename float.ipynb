# %% [markdown]
# <a href="https://colab.research.google.com/github/xbetoxsantos-web/curso-python-piva/blob/main/float.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
type(10.)

#todo divisão é um float
# Out:
# float

# %%
num=10.0
type(num)
# Out:
# float

# %%
type(10/2)
# Out:
# float

# %%
print(10/2)
# Out:
# 5.0
# NoneType

# %%
inteiro=5
nun=int(inteiro)
int(num)
# Out:
# 10

# %%
Num=5+4.6
print(Num)
type(Num)
# Out:
# 9.6
# float

# %%
# Numero completo acompanhado do J

A=5j
type(A)
# Out:
# complex
