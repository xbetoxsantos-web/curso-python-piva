# %% [markdown]
# <a href="https://colab.research.google.com/github/xbetoxsantos-web/curso-python-piva/blob/main/aula_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
''' testando comentários para ver se,
as aspas com 3  vai fncionar
bom , funcionou
isso ai'''

# %%
# desafio vaio copcatenar pq estar em string

x=input('Digite o valor de x: ')
y=input('Digiet o vaor de y: ')
type(x)
type(y)
print('Resultado a soma : ',x+y)
# Out:
# Digite o valor de x: 7
# Digiet o vaor de y: 4
# Resultado a soma :  74

# %%
x=int(input('Digite o valor de x: '))
y=int(input('Digite o valor de y: '))
type(x)
type(y)
print('Resultado da soma:',x+y)
# Out:
# Digite o valor de x: 6
# Digite o valor de y: 7
# Resultado da soma: 13
